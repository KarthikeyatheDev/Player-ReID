# %%
# Install required packages if not installed:
# pip install ultralytics torch torchvision torchreid opencv-python filterpy scikit-learn numpy

# %%
from ultralytics import YOLO
import torch
import torchreid
import cv2
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from filterpy.kalman import KalmanFilter
# Out:
# c:\Users\Karthikeya\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchreid\reid\metrics\rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(

# %%
import os

# Path to your YOLO model weights
yolo_weights_path = 'best.pt'

if not os.path.exists(yolo_weights_path):
	raise FileNotFoundError(f"YOLO weights file not found: {yolo_weights_path}. Please provide the correct path to your model weights.")

# Load YOLOv11 Model
yolo_model = YOLO(yolo_weights_path)

# %%
# Load ReID Model
device = 'cuda' if torch.cuda.is_available() else 'cpu'
reid_model = torchreid.models.build_model(
    name='osnet_x1_0',
    num_classes=1000,
    loss='softmax',
    pretrained=True
)
reid_model.eval().to(device)
# Out:
# Successfully loaded imagenet pretrained weights from "C:\Users\Karthikeya/.cache\torch\checkpoints\osnet_x1_0_imagenet.pth"
# OSNet(
#   (conv1): ConvLayer(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (conv2): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): Conv1x1(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#   )
#   (conv3): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(256, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(96, 6, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(6, 96, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(96, 6, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(6, 96, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): Conv1x1(
#         (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#   )
#   (conv4): Sequential(
#     (0): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Conv1x1Linear(
#         (conv): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): OSBlock(
#       (conv1): Conv1x1(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2a): LightConv3x3(
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2b): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2c): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv2d): Sequential(
#         (0): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): LightConv3x3(
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (gate): ChannelGate(
#         (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#         (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#         (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1))
#         (gate_activation): Sigmoid()
#       )
#       (conv3): Conv1x1Linear(
#         (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv5): Conv1x1(
#     (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (classifier): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
# Preprocessing for ReID
def preprocess(crop):
    if crop is None or crop.size == 0:
        return None
    crop = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)
    crop = cv2.resize(crop, (128, 256))

    img = crop.astype(np.float32) / 255.0
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = (img - mean) / std

    img = torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0).float().to(device)
    return img

def extract_reid_features(crop):
    img_tensor = preprocess(crop)
    if img_tensor is None:
        return None
    with torch.no_grad():
        features = reid_model(img_tensor)
    return features.cpu().numpy().flatten()

# %%
# Kalman Filter initialization
def create_kalman_filter(x, y):
    kf = KalmanFilter(dim_x=4, dim_z=2)
    kf.x = np.array([x, y, 0, 0])
    kf.F = np.array([[1, 0, 1, 0],
                     [0, 1, 0, 1],
                     [0, 0, 1, 0],
                     [0, 0, 0, 1]])
    kf.H = np.array([[1, 0, 0, 0],
                     [0, 1, 0, 0]])
    kf.P *= 1000.
    kf.R *= 10.
    kf.Q *= 0.01
    return kf

# %%
# IoU calculation
def iou(bbox1, bbox2):
    x1, y1, x2, y2 = bbox1
    x1g, y1g, x2g, y2g = bbox2

    xi1, yi1 = max(x1, x1g), max(y1, y1g)
    xi2, yi2 = min(x2, x2g), min(y2, y2g)
    inter_area = max(0, xi2 - xi1) * max(0, yi2 - yi1)

    bbox1_area = (x2 - x1) * (y2 - y1)
    bbox2_area = (x2g - x1g) * (y2g - y1g)

    union_area = bbox1_area + bbox2_area - inter_area
    return inter_area / union_area if union_area > 0 else 0

# %%
# Tracker class
class Tracker:
    def __init__(self, id, bbox, embedding):
        self.id = id
        self.bbox = bbox
        self.embedding = embedding
        cx = (bbox[0] + bbox[2]) / 2
        cy = (bbox[1] + bbox[3]) / 2
        self.kf = create_kalman_filter(cx, cy)
        self.age = 0
        self.missing = 0

    def predict(self):
        self.kf.predict()
        cx, cy = self.kf.x[0], self.kf.x[1]
        w = self.bbox[2] - self.bbox[0]
        h = self.bbox[3] - self.bbox[1]
        self.bbox = (cx - w/2, cy - h/2, cx + w/2, cy + h/2)

    def update(self, bbox, embedding):
        cx = (bbox[0] + bbox[2]) / 2
        cy = (bbox[1] + bbox[3]) / 2
        self.kf.update([cx, cy])
        self.bbox = bbox
        self.embedding = embedding
        self.missing = 0
        self.age += 1

# %%
# Parameters
IOU_THRESHOLD = 0.3
REID_THRESHOLD = 0.7
MAX_MISSING_FRAMES = 30
padding = 20

# Initialize
trackers = []

# Video setup
cap = cv2.VideoCapture('Inputs/15sec_input_720p.mp4')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))

out = cv2.VideoWriter('Output/output_new.mp4',
                      cv2.VideoWriter_fourcc(*'mp4v'),
                      fps,
                      (frame_width, frame_height))

# %%
# Main Loop
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    detections = []
    # Use torch.no_grad() to speed up inference and reduce memory usage
    with torch.no_grad():
        results = yolo_model(frame)

        # Use numpy array only once
        boxes = results[0].boxes.xyxy.cpu().numpy() if hasattr(results[0].boxes.xyxy, 'cpu') else results[0].boxes.xyxy
        for box in boxes:
            x1, y1, x2, y2 = map(int, box[:4])
            x1 = max(0, x1 - padding)
            y1 = max(0, y1 - padding)
            x2 = min(frame.shape[1]-1, x2 + padding)
            y2 = min(frame.shape[0]-1, y2 + padding)

            crop = frame[y1:y2, x1:x2]
            # Only extract features if crop is valid
            if crop.size == 0 or (y2 - y1) <= 0 or (x2 - x1) <= 0:
                continue
            embedding = extract_reid_features(crop)
            if embedding is None:
                continue
            detections.append((x1, y1, x2, y2, embedding))

    # Predict existing trackers (vectorized for performance)
    for tracker in trackers:
        tracker.predict()
        tracker.missing += 1

    matched = set()
    # Precompute tracker embeddings for batch cosine similarity
    tracker_embeddings = np.array([t.embedding for t in trackers]) if trackers else None
    for det in detections:
        x1, y1, x2, y2, embedding = det
        bbox = (x1, y1, x2, y2)

        best_match = None
        best_score = 0

        if tracker_embeddings is not None and len(tracker_embeddings) > 0:
            # Batch cosine similarity for all trackers
            reid_scores = cosine_similarity(embedding.reshape(1, -1), tracker_embeddings)[0]
        else:
            reid_scores = []

        for idx, tracker in enumerate(trackers):
            iou_score = iou(bbox, tracker.bbox)
            reid_score = reid_scores[idx] if len(reid_scores) > idx else 0
            combined = (0.6 * iou_score) + (0.4 * reid_score)

            if combined > best_score and (iou_score > IOU_THRESHOLD or reid_score > REID_THRESHOLD):
                best_score = combined
                best_match = tracker

        if best_match:
            best_match.update(bbox, embedding)
            matched.add(best_match.id)
        else:
            # Assign a human-readable ID (e.g., Player 1, Player 2, ...)
            new_id = f"Player {len(trackers) + 1}"
            trackers.append(Tracker(new_id, bbox, embedding))

    # Remove lost trackers
    trackers = [t for t in trackers if t.missing <= MAX_MISSING_FRAMES]

    # Draw results
    for tracker in trackers:
        x1, y1, x2, y2 = map(int, tracker.bbox)
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f'ID {tracker.id}', (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    out.write(frame)

cap.release()
out.release()
print(f"✅ Processing complete. Total unique IDs: {len(trackers)}")
# Out:
# 0: 384x640 1 ball, 16 players, 2 referees, 191.5ms
# Speed: 13.1ms preprocess, 191.5ms inference, 498.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 68.9ms
# Speed: 2.3ms preprocess, 68.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 66.4ms
# Speed: 3.4ms preprocess, 66.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 70.3ms
# Speed: 2.2ms preprocess, 70.3ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 72.0ms
# Speed: 2.1ms preprocess, 72.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 71.9ms
# Speed: 1.9ms preprocess, 71.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 70.0ms
# Speed: 3.3ms preprocess, 70.0ms inference, 30.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 69.6ms
# Speed: 2.2ms preprocess, 69.6ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 78.2ms
# Speed: 2.1ms preprocess, 78.2ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 73.1ms
# Speed: 2.2ms preprocess, 73.1ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 71.7ms
# Speed: 2.0ms preprocess, 71.7ms inference, 26.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 3 referees, 69.7ms
# Speed: 2.5ms preprocess, 69.7ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 157.7ms
# Speed: 3.6ms preprocess, 157.7ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 67.0ms
# Speed: 3.7ms preprocess, 67.0ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 67.6ms
# Speed: 2.1ms preprocess, 67.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 70.9ms
# Speed: 2.4ms preprocess, 70.9ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 67.2ms
# Speed: 2.2ms preprocess, 67.2ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 67.5ms
# Speed: 1.9ms preprocess, 67.5ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 68.0ms
# Speed: 2.1ms preprocess, 68.0ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 66.8ms
# Speed: 2.7ms preprocess, 66.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 67.8ms
# Speed: 1.8ms preprocess, 67.8ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 69.5ms
# Speed: 1.9ms preprocess, 69.5ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 70.5ms
# Speed: 3.1ms preprocess, 70.5ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 76.6ms
# Speed: 2.5ms preprocess, 76.6ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 145.0ms
# Speed: 2.4ms preprocess, 145.0ms inference, 19.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 73.9ms
# Speed: 2.7ms preprocess, 73.9ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 72.0ms
# Speed: 2.3ms preprocess, 72.0ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 2 referees, 72.5ms
# Speed: 3.1ms preprocess, 72.5ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 16 players, 2 referees, 76.9ms
# Speed: 1.9ms preprocess, 76.9ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 15 players, 2 referees, 70.3ms
# Speed: 3.9ms preprocess, 70.3ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 91.6ms
# Speed: 3.8ms preprocess, 91.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 109.0ms
# Speed: 3.9ms preprocess, 109.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 82.0ms
# Speed: 5.4ms preprocess, 82.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 73.3ms
# Speed: 4.1ms preprocess, 73.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3 referees, 94.4ms
# Speed: 4.1ms preprocess, 94.4ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 87.2ms
# Speed: 3.9ms preprocess, 87.2ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 82.3ms
# Speed: 3.2ms preprocess, 82.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 73.6ms
# Speed: 3.9ms preprocess, 73.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 69.6ms
# Speed: 4.8ms preprocess, 69.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 3 referees, 68.9ms
# Speed: 3.5ms preprocess, 68.9ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 76.1ms
# Speed: 4.7ms preprocess, 76.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 68.9ms
# Speed: 3.6ms preprocess, 68.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 68.0ms
# Speed: 3.6ms preprocess, 68.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 68.8ms
# Speed: 4.5ms preprocess, 68.8ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 68.4ms
# Speed: 4.9ms preprocess, 68.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 67.3ms
# Speed: 4.2ms preprocess, 67.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 83.5ms
# Speed: 3.8ms preprocess, 83.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 72.9ms
# Speed: 3.7ms preprocess, 72.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 91.8ms
# Speed: 3.4ms preprocess, 91.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 82.8ms
# Speed: 3.7ms preprocess, 82.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 3 referees, 75.8ms
# Speed: 3.8ms preprocess, 75.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 104.2ms
# Speed: 4.9ms preprocess, 104.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 82.1ms
# Speed: 3.9ms preprocess, 82.1ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 74.0ms
# Speed: 3.9ms preprocess, 74.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 71.1ms
# Speed: 3.2ms preprocess, 71.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 67.3ms
# Speed: 3.6ms preprocess, 67.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 65.7ms
# Speed: 2.3ms preprocess, 65.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 67.2ms
# Speed: 2.0ms preprocess, 67.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 65.6ms
# Speed: 2.8ms preprocess, 65.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 67.4ms
# Speed: 2.2ms preprocess, 67.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 67.5ms
# Speed: 2.4ms preprocess, 67.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 66.9ms
# Speed: 2.2ms preprocess, 66.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 4 referees, 69.8ms
# Speed: 2.1ms preprocess, 69.8ms inference, 20.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 4 referees, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 66.9ms
# Speed: 2.2ms preprocess, 66.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 68.0ms
# Speed: 1.9ms preprocess, 68.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 66.0ms
# Speed: 1.9ms preprocess, 66.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 66.9ms
# Speed: 1.9ms preprocess, 66.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 68.0ms
# Speed: 1.9ms preprocess, 68.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 67.0ms
# Speed: 2.7ms preprocess, 67.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 67.2ms
# Speed: 2.3ms preprocess, 67.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 67.5ms
# Speed: 2.5ms preprocess, 67.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 66.5ms
# Speed: 4.5ms preprocess, 66.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 66.9ms
# Speed: 3.9ms preprocess, 66.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 78.2ms
# Speed: 3.7ms preprocess, 78.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 73.3ms
# Speed: 3.9ms preprocess, 73.3ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 70.7ms
# Speed: 4.2ms preprocess, 70.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 66.5ms
# Speed: 2.5ms preprocess, 66.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 70.7ms
# Speed: 1.8ms preprocess, 70.7ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 68.2ms
# Speed: 2.6ms preprocess, 68.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 67.8ms
# Speed: 2.3ms preprocess, 67.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 68.7ms
# Speed: 2.0ms preprocess, 68.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 69.6ms
# Speed: 2.5ms preprocess, 69.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 67.2ms
# Speed: 1.9ms preprocess, 67.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 68.6ms
# Speed: 2.2ms preprocess, 68.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 67.3ms
# Speed: 2.1ms preprocess, 67.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 68.6ms
# Speed: 2.8ms preprocess, 68.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 117.6ms
# Speed: 2.0ms preprocess, 117.6ms inference, 23.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 68.8ms
# Speed: 3.4ms preprocess, 68.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 75.0ms
# Speed: 2.1ms preprocess, 75.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 70.0ms
# Speed: 2.7ms preprocess, 70.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 68.1ms
# Speed: 2.4ms preprocess, 68.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 68.4ms
# Speed: 2.1ms preprocess, 68.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 68.9ms
# Speed: 2.3ms preprocess, 68.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 69.6ms
# Speed: 2.5ms preprocess, 69.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 68.3ms
# Speed: 2.6ms preprocess, 68.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 68.2ms
# Speed: 2.3ms preprocess, 68.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 67.9ms
# Speed: 2.0ms preprocess, 67.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 71.6ms
# Speed: 2.1ms preprocess, 71.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 71.0ms
# Speed: 2.4ms preprocess, 71.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 70.7ms
# Speed: 3.6ms preprocess, 70.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 17 players, 69.9ms
# Speed: 2.0ms preprocess, 69.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 69.5ms
# Speed: 3.6ms preprocess, 69.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 68.6ms
# Speed: 3.4ms preprocess, 68.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 68.0ms
# Speed: 1.9ms preprocess, 68.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 69.4ms
# Speed: 2.0ms preprocess, 69.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 69.2ms
# Speed: 1.9ms preprocess, 69.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 69.3ms
# Speed: 3.4ms preprocess, 69.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 71.1ms
# Speed: 2.7ms preprocess, 71.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 68.3ms
# Speed: 2.1ms preprocess, 68.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 69.1ms
# Speed: 2.6ms preprocess, 69.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 70.2ms
# Speed: 1.8ms preprocess, 70.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 70.6ms
# Speed: 2.3ms preprocess, 70.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 70.8ms
# Speed: 2.0ms preprocess, 70.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 70.5ms
# Speed: 2.5ms preprocess, 70.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 70.1ms
# Speed: 2.4ms preprocess, 70.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 70.3ms
# Speed: 2.5ms preprocess, 70.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 70.2ms
# Speed: 2.2ms preprocess, 70.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 69.8ms
# Speed: 3.1ms preprocess, 69.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 69.7ms
# Speed: 2.2ms preprocess, 69.7ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 68.9ms
# Speed: 2.4ms preprocess, 68.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 92.3ms
# Speed: 3.2ms preprocess, 92.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 68.6ms
# Speed: 2.1ms preprocess, 68.6ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 18 players, 1 referee, 69.3ms
# Speed: 1.8ms preprocess, 69.3ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 66.9ms
# Speed: 2.5ms preprocess, 66.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 67.7ms
# Speed: 2.1ms preprocess, 67.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 68.2ms
# Speed: 2.0ms preprocess, 68.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 68.5ms
# Speed: 1.9ms preprocess, 68.5ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 1 referee, 68.4ms
# Speed: 2.2ms preprocess, 68.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 68.8ms
# Speed: 1.9ms preprocess, 68.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 70.8ms
# Speed: 1.9ms preprocess, 70.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 71.8ms
# Speed: 2.3ms preprocess, 71.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 72.4ms
# Speed: 1.9ms preprocess, 72.4ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 103.1ms
# Speed: 2.2ms preprocess, 103.1ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 82.0ms
# Speed: 2.4ms preprocess, 82.0ms inference, 20.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 69.6ms
# Speed: 2.4ms preprocess, 69.6ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 114.9ms
# Speed: 2.7ms preprocess, 114.9ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 69.4ms
# Speed: 2.6ms preprocess, 69.4ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 68.1ms
# Speed: 2.7ms preprocess, 68.1ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 67.4ms
# Speed: 2.3ms preprocess, 67.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 68.6ms
# Speed: 4.5ms preprocess, 68.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 68.9ms
# Speed: 2.3ms preprocess, 68.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 68.8ms
# Speed: 1.7ms preprocess, 68.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 69.0ms
# Speed: 3.5ms preprocess, 69.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 108.5ms
# Speed: 2.6ms preprocess, 108.5ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 69.3ms
# Speed: 2.5ms preprocess, 69.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 68.3ms
# Speed: 1.7ms preprocess, 68.3ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 69.0ms
# Speed: 1.9ms preprocess, 69.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 69.8ms
# Speed: 2.1ms preprocess, 69.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 68.1ms
# Speed: 1.8ms preprocess, 68.1ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 67.4ms
# Speed: 1.8ms preprocess, 67.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 68.5ms
# Speed: 1.8ms preprocess, 68.5ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 67.0ms
# Speed: 2.6ms preprocess, 67.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 68.8ms
# Speed: 2.2ms preprocess, 68.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 69.6ms
# Speed: 1.8ms preprocess, 69.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 70.6ms
# Speed: 3.2ms preprocess, 70.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 71.5ms
# Speed: 2.7ms preprocess, 71.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 71.0ms
# Speed: 1.8ms preprocess, 71.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 71.5ms
# Speed: 2.1ms preprocess, 71.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 70.6ms
# Speed: 2.4ms preprocess, 70.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 68.4ms
# Speed: 1.9ms preprocess, 68.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 69.7ms
# Speed: 2.8ms preprocess, 69.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 70.2ms
# Speed: 2.0ms preprocess, 70.2ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 68.9ms
# Speed: 2.0ms preprocess, 68.9ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 69.6ms
# Speed: 1.8ms preprocess, 69.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.4ms
# Speed: 2.1ms preprocess, 68.4ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 68.6ms
# Speed: 1.8ms preprocess, 68.6ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 11 players, 1 referee, 70.0ms
# Speed: 1.9ms preprocess, 70.0ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 69.5ms
# Speed: 1.9ms preprocess, 69.5ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 68.8ms
# Speed: 2.1ms preprocess, 68.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 68.9ms
# Speed: 2.1ms preprocess, 68.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 70.5ms
# Speed: 2.7ms preprocess, 70.5ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 68.8ms
# Speed: 2.4ms preprocess, 68.8ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 68.0ms
# Speed: 2.3ms preprocess, 68.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 68.7ms
# Speed: 1.8ms preprocess, 68.7ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 69.1ms
# Speed: 1.9ms preprocess, 69.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1 referee, 68.8ms
# Speed: 2.5ms preprocess, 68.8ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 67.7ms
# Speed: 3.8ms preprocess, 67.7ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 68.4ms
# Speed: 2.3ms preprocess, 68.4ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 69.5ms
# Speed: 2.4ms preprocess, 69.5ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 14 players, 67.9ms
# Speed: 4.2ms preprocess, 67.9ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 68.2ms
# Speed: 3.7ms preprocess, 68.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 70.7ms
# Speed: 2.2ms preprocess, 70.7ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 70.4ms
# Speed: 2.1ms preprocess, 70.4ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 70.2ms
# Speed: 2.5ms preprocess, 70.2ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 69.3ms
# Speed: 2.0ms preprocess, 69.3ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 70.3ms
# Speed: 4.2ms preprocess, 70.3ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 68.0ms
# Speed: 1.9ms preprocess, 68.0ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 68.2ms
# Speed: 2.1ms preprocess, 68.2ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 68.1ms
# Speed: 2.2ms preprocess, 68.1ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 69.3ms
# Speed: 2.1ms preprocess, 69.3ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 68.6ms
# Speed: 2.9ms preprocess, 68.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 68.1ms
# Speed: 2.2ms preprocess, 68.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 69.0ms
# Speed: 1.8ms preprocess, 69.0ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.1ms
# Speed: 1.7ms preprocess, 68.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 67.7ms
# Speed: 2.1ms preprocess, 67.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 69.2ms
# Speed: 2.0ms preprocess, 69.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.8ms
# Speed: 1.9ms preprocess, 68.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 69.2ms
# Speed: 3.8ms preprocess, 69.2ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 71.0ms
# Speed: 4.1ms preprocess, 71.0ms inference, 25.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 129.1ms
# Speed: 2.7ms preprocess, 129.1ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 10 players, 132.8ms
# Speed: 2.5ms preprocess, 132.8ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 71.0ms
# Speed: 2.2ms preprocess, 71.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 72.2ms
# Speed: 2.1ms preprocess, 72.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 69.3ms
# Speed: 1.9ms preprocess, 69.3ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 70.0ms
# Speed: 2.6ms preprocess, 70.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 70.2ms
# Speed: 1.8ms preprocess, 70.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 70.0ms
# Speed: 1.8ms preprocess, 70.0ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 69.7ms
# Speed: 1.8ms preprocess, 69.7ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 69.7ms
# Speed: 1.9ms preprocess, 69.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 68.5ms
# Speed: 1.8ms preprocess, 68.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 9 players, 69.6ms
# Speed: 1.8ms preprocess, 69.6ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 68.2ms
# Speed: 2.2ms preprocess, 68.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 67.9ms
# Speed: 2.6ms preprocess, 67.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 66.6ms
# Speed: 2.2ms preprocess, 66.6ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 70.9ms
# Speed: 2.6ms preprocess, 70.9ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 8 players, 69.3ms
# Speed: 1.9ms preprocess, 69.3ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 67.7ms
# Speed: 1.9ms preprocess, 67.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 66.4ms
# Speed: 2.0ms preprocess, 66.4ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 66.4ms
# Speed: 1.9ms preprocess, 66.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 67.5ms
# Speed: 2.2ms preprocess, 67.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 71.9ms
# Speed: 2.1ms preprocess, 71.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 68.8ms
# Speed: 1.6ms preprocess, 68.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 69.6ms
# Speed: 1.9ms preprocess, 69.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 68.7ms
# Speed: 2.9ms preprocess, 68.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 68.4ms
# Speed: 1.8ms preprocess, 68.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 69.8ms
# Speed: 1.8ms preprocess, 69.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 69.4ms
# Speed: 3.2ms preprocess, 69.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 68.1ms
# Speed: 1.8ms preprocess, 68.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 69.2ms
# Speed: 2.5ms preprocess, 69.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 68.6ms
# Speed: 3.4ms preprocess, 68.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 104.5ms
# Speed: 3.1ms preprocess, 104.5ms inference, 20.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 69.7ms
# Speed: 2.5ms preprocess, 69.7ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 67.7ms
# Speed: 3.1ms preprocess, 67.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 67.7ms
# Speed: 1.8ms preprocess, 67.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 69.7ms
# Speed: 2.2ms preprocess, 69.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 69.8ms
# Speed: 2.4ms preprocess, 69.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 70.2ms
# Speed: 2.0ms preprocess, 70.2ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 71.0ms
# Speed: 1.8ms preprocess, 71.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 68.3ms
# Speed: 2.4ms preprocess, 68.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 67.3ms
# Speed: 2.1ms preprocess, 67.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 67.8ms
# Speed: 2.2ms preprocess, 67.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 69.0ms
# Speed: 2.4ms preprocess, 69.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 68.1ms
# Speed: 2.1ms preprocess, 68.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 68.0ms
# Speed: 3.1ms preprocess, 68.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 68.1ms
# Speed: 1.9ms preprocess, 68.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 69.8ms
# Speed: 2.2ms preprocess, 69.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 69.1ms
# Speed: 3.0ms preprocess, 69.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 69.5ms
# Speed: 2.1ms preprocess, 69.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 69.2ms
# Speed: 1.9ms preprocess, 69.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 70.5ms
# Speed: 1.9ms preprocess, 70.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 70.4ms
# Speed: 2.8ms preprocess, 70.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 68.6ms
# Speed: 3.8ms preprocess, 68.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 69.4ms
# Speed: 2.5ms preprocess, 69.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 71.5ms
# Speed: 2.5ms preprocess, 71.5ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 71.3ms
# Speed: 2.3ms preprocess, 71.3ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 73.1ms
# Speed: 2.1ms preprocess, 73.1ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 170.9ms
# Speed: 4.6ms preprocess, 170.9ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 68.2ms
# Speed: 2.2ms preprocess, 68.2ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 70.6ms
# Speed: 2.2ms preprocess, 70.6ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 69.2ms
# Speed: 1.9ms preprocess, 69.2ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 67.4ms
# Speed: 1.8ms preprocess, 67.4ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 68.3ms
# Speed: 2.5ms preprocess, 68.3ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 68.6ms
# Speed: 2.2ms preprocess, 68.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 66.8ms
# Speed: 1.8ms preprocess, 66.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 67.5ms
# Speed: 1.9ms preprocess, 67.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 70.2ms
# Speed: 3.1ms preprocess, 70.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 67.5ms
# Speed: 3.4ms preprocess, 67.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 69.8ms
# Speed: 2.1ms preprocess, 69.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 69.9ms
# Speed: 2.3ms preprocess, 69.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 69.8ms
# Speed: 2.8ms preprocess, 69.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 69.3ms
# Speed: 2.2ms preprocess, 69.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 69.7ms
# Speed: 1.9ms preprocess, 69.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 31.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 69.8ms
# Speed: 2.2ms preprocess, 69.8ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 71.2ms
# Speed: 2.6ms preprocess, 71.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 120.4ms
# Speed: 4.0ms preprocess, 120.4ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 116.0ms
# Speed: 3.1ms preprocess, 116.0ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 69.4ms
# Speed: 2.2ms preprocess, 69.4ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 99.3ms
# Speed: 2.2ms preprocess, 99.3ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 116.9ms
# Speed: 4.6ms preprocess, 116.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 70.0ms
# Speed: 2.1ms preprocess, 70.0ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 69.4ms
# Speed: 1.9ms preprocess, 69.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 68.9ms
# Speed: 3.3ms preprocess, 68.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 67.3ms
# Speed: 2.1ms preprocess, 67.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 68.4ms
# Speed: 1.9ms preprocess, 68.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 67.3ms
# Speed: 1.7ms preprocess, 67.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 68.5ms
# Speed: 2.8ms preprocess, 68.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 68.7ms
# Speed: 2.0ms preprocess, 68.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 69.9ms
# Speed: 2.8ms preprocess, 69.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 69.5ms
# Speed: 1.9ms preprocess, 69.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 70.6ms
# Speed: 1.9ms preprocess, 70.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 70.4ms
# Speed: 2.3ms preprocess, 70.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 70.9ms
# Speed: 2.1ms preprocess, 70.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 68.0ms
# Speed: 2.1ms preprocess, 68.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 68.2ms
# Speed: 2.1ms preprocess, 68.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 70.0ms
# Speed: 2.2ms preprocess, 70.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 69.2ms
# Speed: 4.3ms preprocess, 69.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 69.3ms
# Speed: 3.2ms preprocess, 69.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 68.3ms
# Speed: 1.9ms preprocess, 68.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 70.7ms
# Speed: 2.1ms preprocess, 70.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 68.9ms
# Speed: 2.1ms preprocess, 68.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 68.5ms
# Speed: 1.8ms preprocess, 68.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 70.5ms
# Speed: 1.8ms preprocess, 70.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 70.2ms
# Speed: 2.2ms preprocess, 70.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 70.1ms
# Speed: 3.2ms preprocess, 70.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 69.5ms
# Speed: 2.0ms preprocess, 69.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 68.2ms
# Speed: 1.9ms preprocess, 68.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 68.9ms
# Speed: 2.4ms preprocess, 68.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 70.1ms
# Speed: 3.7ms preprocess, 70.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 68.4ms
# Speed: 2.2ms preprocess, 68.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 70.1ms
# Speed: 4.3ms preprocess, 70.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 69.6ms
# Speed: 2.5ms preprocess, 69.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 69.6ms
# Speed: 2.1ms preprocess, 69.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.9ms
# Speed: 2.1ms preprocess, 68.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 69.3ms
# Speed: 2.5ms preprocess, 69.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 67.6ms
# Speed: 2.4ms preprocess, 67.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.8ms
# Speed: 2.2ms preprocess, 68.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.1ms
# Speed: 2.4ms preprocess, 68.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.1ms
# Speed: 2.4ms preprocess, 68.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.6ms
# Speed: 1.9ms preprocess, 68.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 73.9ms
# Speed: 2.1ms preprocess, 73.9ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 69.9ms
# Speed: 2.0ms preprocess, 69.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 69.3ms
# Speed: 1.8ms preprocess, 69.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 71.0ms
# Speed: 2.1ms preprocess, 71.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 69.7ms
# Speed: 2.0ms preprocess, 69.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 71.4ms
# Speed: 2.2ms preprocess, 71.4ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 71.1ms
# Speed: 2.3ms preprocess, 71.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 71.6ms
# Speed: 2.4ms preprocess, 71.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.5ms
# Speed: 3.2ms preprocess, 68.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 67.6ms
# Speed: 2.2ms preprocess, 67.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 68.2ms
# Speed: 2.0ms preprocess, 68.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 67.8ms
# Speed: 2.1ms preprocess, 67.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 68.6ms
# Speed: 3.5ms preprocess, 68.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 70.5ms
# Speed: 3.1ms preprocess, 70.5ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 68.2ms
# Speed: 1.9ms preprocess, 68.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 67.3ms
# Speed: 2.2ms preprocess, 67.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 67.2ms
# Speed: 2.1ms preprocess, 67.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 2.8ms preprocess, 67.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 68.3ms
# Speed: 2.8ms preprocess, 68.3ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 67.6ms
# Speed: 3.4ms preprocess, 67.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 68.3ms
# Speed: 2.4ms preprocess, 68.3ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processing complete. Total unique IDs: 14
